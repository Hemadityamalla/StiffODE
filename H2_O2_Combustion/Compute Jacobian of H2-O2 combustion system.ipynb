# %%
from sympy import symbols, diff, Matrix, init_printing
init_printing()

# %%
ko,ki = symbols("k0,k\infty")
kf1,kr1 = symbols("k_{f_1}, k_{r_1}")
kf2,kr2 = symbols("k_{f_2}, k_{r_2}")
kf3,kr3 = symbols("k_{f_3}, k_{r_3}")
ko4,ki4 = symbols("k_{0_4}, k_{\infty_4}")
kf5,kr5 = symbols("k_{f_5}, k_{r_5}")
kf6,kr6 = symbols("k_{f_6}, k_{r_6}")
kf7,kr7 = symbols("k_{f_7}, k_{r_7}")
kf8,kr8 = symbols("k_{f_8}, k_{r_8}")
kf9,kr9 = symbols("k_{f_9}, k_{r_9}")
kf10,kr10 = symbols("k_{f_{10}}, k_{r_{10}}")
kf11,kr11 = symbols("k_{f_{11}}, k_{r_{11}}")
ko12,ki12 = symbols("k_{0_{12}}, k_{\infty_{12}}")


y1, y2, y3, y4, y5, y6, y7, y8 = symbols("y_1,y_2,y_3,y_4,y_5,y_6,y_7,y_8")
Pr4 = (ko4/ki4)*(2.5*y1 + y2 + 16*y3 + y4 + y5 + y6 + y7 + y8)
Pr12 = (ko12/ki12)*(2.5*y1 + y2 + 6*y3 + y4 + y5 + y6 + y7 + y8)

# %%
r1 = kf1*y4*y2 - kr1*y6*y5
r2 = kf2*y1*y5 - kr2*y4*y6
r3 = kf3*y1*y6 - kr3*y3*y4
r4 = (ko4/(1 + Pr4))*y2*y4
r5 = kf5*y7*y4
r6 = kf6*y7*y4 - kr6*y1*y2
r7 = kf7*y7*y6
r8 = kf8*y4*y6 - kr8*y3
r9 = kf9*y4**2 - kr9*y1
r10 = kf10*y7**2
r11 = kf11*y7*y1
r12 = (ki12*Pr12/(1 + Pr12))*y8

# %%
f1 = -r2 -  r3 + r6 + r9 - r11
f2 = -r1 - r4 + r6 + r7 + r10
f3 = r3 + r7 + r8
f4 = -r1 + r2 + r3 - r4 - r5 - r6 + r11
f5 = r1 - r2
f6 = r1 + r2 - r3 + 2*r5 - r7 - r8 + 2*r12
f7 = r4 - r5 - r6 - r7 - 2*r10 - r11
f8 = r10 + r11

# %%
F = Matrix([f1,f2,f3,f4,f5,f6,f7,f8])
y = Matrix([y1, y2, y3, y4, y5, y6, y7, y8])

# %%
F.jacobian(y)
# Out:
# ⎡                                                     -k_{f_2}⋅y₅ - k_{f_3}⋅y₆
# ⎢
# ⎢
# ⎢                                                                     2.5⋅k_{0
# ⎢                                         ────────────────────────────────────
# ⎢
# ⎢                                                      ⎛k_{0_4}⋅(2.5⋅y₁ + y₂ +
# ⎢                                         k_{\infty_4}⋅⎜──────────────────────
# ⎢                                                      ⎝                     k
# ⎢
# ⎢
# ⎢
# ⎢                                                           2
# ⎢                                                2.5⋅k_{0_4} ⋅y₂⋅y₄
# ⎢                    ─────────────────────────────────────────────────────────
# ⎢
# ⎢                                 ⎛k_{0_4}⋅(2.5⋅y₁ + y₂ + 16⋅y₃ + y₄ + y₅ + y₆
# ⎢                    k_{\infty_4}⋅⎜───────────────────────────────────────────
# ⎢                                 ⎝                     k_{\infty_4}
# ⎢
# ⎢
# ⎢
# ⎢                        2
# ⎢          5.0⋅k_{0_{12}} ⋅y₈⋅(2.5⋅y₁ + y₂ + 6⋅y₃ + y₄ + y₅ + y₆ + y₇ + y₈)
# ⎢- ───────────────────────────────────────────────────────────────────────────
# ⎢
# ⎢                  ⎛k_{0_{12}}⋅(2.5⋅y₁ + y₂ + 6⋅y₃ + y₄ + y₅ + y₆ + y₇ + y₈)
# ⎢  k_{\infty_{12}}⋅⎜──────────────────────────────────────────────────────── +
# ⎢                  ⎝                    k_{\infty_{12}}
# ⎢
# ⎢                                                                         2
# ⎢                                                              2.5⋅k_{0_4} ⋅y₂
# ⎢                                - ───────────────────────────────────────────
# ⎢
# ⎢                                               ⎛k_{0_4}⋅(2.5⋅y₁ + y₂ + 16⋅y₃
# ⎢                                  k_{\infty_4}⋅⎜─────────────────────────────
# ⎢                                               ⎝                     k_{\inft
# ⎢
# ⎣
#
#  - k_{f_{11}}⋅y₇ - k_{r_6}⋅y₂ - k_{r_9}
#
#    2
# _4} ⋅y₂⋅y₄
# ────────────────────────────────────── - k_{r_6}⋅y₂
#                                      2
#  16⋅y₃ + y₄ + y₅ + y₆ + y₇ + y₈)    ⎞
# ──────────────────────────────── + 1⎟
# _{\infty_4}                         ⎠
#
#    k_{f_3}⋅y₆
#
#
#
# ───────────────── + k_{f_2}⋅y₅ + k_{f_3}⋅y₆ + k_{f_{11}}⋅y₇ + k_{r_6}⋅y₂
#                 2
#  + y₇ + y₈)    ⎞
# ─────────── + 1⎟
#                ⎠
#
#   -k_{f_2}⋅y₅
#
#
#                             5.0⋅k_{0_{12}}⋅y₈
# ──── + ──────────────────────────────────────────────────────────── + k_{f_2}⋅
#    2   k_{0_{12}}⋅(2.5⋅y₁ + y₂ + 6⋅y₃ + y₄ + y₅ + y₆ + y₇ + y₈)
#   ⎞    ──────────────────────────────────────────────────────── + 1
#  1⎟                        k_{\infty_{12}}
#   ⎠
#
#
# ⋅y₄
# ─────────────────────────────── - k_{f_{11}}⋅y₇ + k_{r_6}⋅y₂
#                               2
# + y₄ + y₅ + y₆ + y₇ + y₈)    ⎞
# ───────────────────────── + 1⎟
# y_4}                         ⎠
#
#  k_{f_{11}}⋅y₇
#
#
#
#                                                       2
#                                                k_{0_4} ⋅y₂⋅y₄
#                  ─────────────────────────────────────────────────────────────
#
#                               ⎛k_{0_4}⋅(2.5⋅y₁ + y₂ + 16⋅y₃ + y₄ + y₅ + y₆ + y
#                  k_{\infty_4}⋅⎜───────────────────────────────────────────────
#                               ⎝                     k_{\infty_4}
#
#
#
#                                                       2
#                                                k_{0_4} ⋅y₂⋅y₄
#                  ─────────────────────────────────────────────────────────────
#
#                               ⎛k_{0_4}⋅(2.5⋅y₁ + y₂ + 16⋅y₃ + y₄ + y₅ + y₆ + y
#                  k_{\infty_4}⋅⎜───────────────────────────────────────────────
#                               ⎝                     k_{\infty_4}
#
#
#
#                                           2
#                               2⋅k_{0_{12}} ⋅y₈⋅(2.5⋅y₁ + y₂ + 6⋅y₃ + y₄ + y₅ +
# y₅ - k_{f_3}⋅y₆    - ─────────────────────────────────────────────────────────
#
#                                      ⎛k_{0_{12}}⋅(2.5⋅y₁ + y₂ + 6⋅y₃ + y₄ + y₅
#                      k_{\infty_{12}}⋅⎜────────────────────────────────────────
#                                      ⎝                    k_{\infty_{12}}
#
#                                                              2
#                                                       k_{0_4} ⋅y₂⋅y₄
#                       - ──────────────────────────────────────────────────────
#
#                                      ⎛k_{0_4}⋅(2.5⋅y₁ + y₂ + 16⋅y₃ + y₄ + y₅ +
#                         k_{\infty_4}⋅⎜────────────────────────────────────────
#                                      ⎝                     k_{\infty_4}
#
#
#
#               -k_{r_6}⋅y₁
#
#
#                                         k_{0_4}⋅y₄
# ───────────── - ────────────────────────────────────────────────────────── - k
#             2   k_{0_4}⋅(2.5⋅y₁ + y₂ + 16⋅y₃ + y₄ + y₅ + y₆ + y₇ + y₈)
# ₇ + y₈)    ⎞    ────────────────────────────────────────────────────── + 1
# ─────── + 1⎟                         k_{\infty_4}
#            ⎠
#
#                    0
#
#
#                                         k_{0_4}⋅y₄
# ───────────── - ────────────────────────────────────────────────────────── - k
#             2   k_{0_4}⋅(2.5⋅y₁ + y₂ + 16⋅y₃ + y₄ + y₅ + y₆ + y₇ + y₈)
# ₇ + y₈)    ⎞    ────────────────────────────────────────────────────── + 1
# ─────── + 1⎟                         k_{\infty_4}
#            ⎠
#
#               k_{f_1}⋅y₄
#
#
#  y₆ + y₇ + y₈)                                 2⋅k_{0_{12}}⋅y₈
# ────────────────────── + ─────────────────────────────────────────────────────
#                      2   k_{0_{12}}⋅(2.5⋅y₁ + y₂ + 6⋅y₃ + y₄ + y₅ + y₆ + y₇ +
#  + y₆ + y₇ + y₈)    ⎞    ─────────────────────────────────────────────────────
# ──────────────── + 1⎟                        k_{\infty_{12}}
#                     ⎠
#
#
#                                                k_{0_4}⋅y₄
# ──────────────────── + ───────────────────────────────────────────────────────
#                    2   k_{0_4}⋅(2.5⋅y₁ + y₂ + 16⋅y₃ + y₄ + y₅ + y₆ + y₇ + y₈)
#  y₆ + y₇ + y₈)    ⎞    ──────────────────────────────────────────────────────
# ────────────── + 1⎟                         k_{\infty_4}
#                   ⎠
#
#                    0
#
#
#
#
#
# _{f_1}⋅y₄ - k_{r_6}⋅y₁                                                ────────
#
#
#                                                                       k_{\inft
#
#
#
#
#
#
# _{f_1}⋅y₄ + k_{r_6}⋅y₁                                          ──────────────
#
#                                                                              ⎛
#                                                                 k_{\infty_4}⋅⎜
#                                                                              ⎝
#
#
#
#                                                2
#                                   12⋅k_{0_{12}} ⋅y₈⋅(2.5⋅y₁ + y₂ + 6⋅y₃ + y₄ +
# ─────── + k_{f_1}⋅y₄    - ────────────────────────────────────────────────────
# y₈)
# ─── + 1                                   ⎛k_{0_{12}}⋅(2.5⋅y₁ + y₂ + 6⋅y₃ + y₄
#                           k_{\infty_{12}}⋅⎜───────────────────────────────────
#                                           ⎝                    k_{\infty_{12}}
#
#
#
# ─── + k_{r_6}⋅y₁                                                      ────────
#
# + 1
#                                                                       k_{\inft
#
#
#
#
#                         k_{r_3}⋅y₄
#
#                               2
#                     16⋅k_{0_4} ⋅y₂⋅y₄
# ──────────────────────────────────────────────────────────────────
#                                                                  2
#      ⎛k_{0_4}⋅(2.5⋅y₁ + y₂ + 16⋅y₃ + y₄ + y₅ + y₆ + y₇ + y₈)    ⎞
# y_4}⋅⎜────────────────────────────────────────────────────── + 1⎟
#      ⎝                     k_{\infty_4}                         ⎠
#
#                    -k_{r_3}⋅y₄ - k_{r_8}
#
#                         2
#               16⋅k_{0_4} ⋅y₂⋅y₄
# ──────────────────────────────────────────────────────────── - k_{r_3}⋅y₄
#                                                            2
# k_{0_4}⋅(2.5⋅y₁ + y₂ + 16⋅y₃ + y₄ + y₅ + y₆ + y₇ + y₈)    ⎞
# ────────────────────────────────────────────────────── + 1⎟
#                      k_{\infty_4}                         ⎠
#
#                              0
#
#
#  y₅ + y₆ + y₇ + y₈)                                 12⋅k_{0_{12}}⋅y₈
# ─────────────────────────── + ────────────────────────────────────────────────
#                           2   k_{0_{12}}⋅(2.5⋅y₁ + y₂ + 6⋅y₃ + y₄ + y₅ + y₆ +
#  + y₅ + y₆ + y₇ + y₈)    ⎞    ────────────────────────────────────────────────
# ───────────────────── + 1⎟                        k_{\infty_{12}}
#                          ⎠
#
#                               2
#                    -16⋅k_{0_4} ⋅y₂⋅y₄
# ──────────────────────────────────────────────────────────────────
#                                                                  2
#      ⎛k_{0_4}⋅(2.5⋅y₁ + y₂ + 16⋅y₃ + y₄ + y₅ + y₆ + y₇ + y₈)    ⎞
# y_4}⋅⎜────────────────────────────────────────────────────── + 1⎟
#      ⎝                     k_{\infty_4}                         ⎠
#
#                              0
#
#
#
#
#
#                                                               ────────────────
#
#                                                                            ⎛k_
#                                                               k_{\infty_4}⋅⎜──
#                                                                            ⎝
#
#
#
#
#                                                                         k_{0_4
#                                           ────────────────────────────────────
#
#                                                        ⎛k_{0_4}⋅(2.5⋅y₁ + y₂ +
#                                           k_{\infty_4}⋅⎜──────────────────────
#                                                        ⎝                     k
#
#
#
#                                                             2
#                                                 2⋅k_{0_{12}} ⋅y₈⋅(2.5⋅y₁ + y₂
# ──────────── + k_{r_3}⋅y₄ + k_{r_8}  - ───────────────────────────────────────
# y₇ + y₈)
# ──────── + 1                                           ⎛k_{0_{12}}⋅(2.5⋅y₁ + y
#                                        k_{\infty_{12}}⋅⎜──────────────────────
#                                                        ⎝                    k_
#
#
#
#                                                              - ───────────────
#
#                                                                             ⎛k
#                                                                k_{\infty_4}⋅⎜─
#                                                                             ⎝
#
#
#
#                                        k_{f_6}⋅y₇ + 2⋅k_{f_9}⋅y₄ + k_{r_2}⋅y₆
#
#                      2
#               k_{0_4} ⋅y₂⋅y₄
# ────────────────────────────────────────────────────────── - ─────────────────
#                                                          2   k_{0_4}⋅(2.5⋅y₁ +
# {0_4}⋅(2.5⋅y₁ + y₂ + 16⋅y₃ + y₄ + y₅ + y₆ + y₇ + y₈)    ⎞    ─────────────────
# ──────────────────────────────────────────────────── + 1⎟
#                    k_{\infty_4}                         ⎠
#
#                                                      k_{f_8}⋅y₆ - k_{r_3}⋅y₃
#
#  2
# } ⋅y₂⋅y₄                                                         k_{0_4}⋅y₂
# ────────────────────────────────────── - ─────────────────────────────────────
#                                      2   k_{0_4}⋅(2.5⋅y₁ + y₂ + 16⋅y₃ + y₄ + y
#  16⋅y₃ + y₄ + y₅ + y₆ + y₇ + y₈)    ⎞    ─────────────────────────────────────
# ──────────────────────────────── + 1⎟                         k_{\infty_4}
# _{\infty_4}                         ⎠
#
#                                                      k_{f_1}⋅y₂ + k_{r_2}⋅y₆
#
#
# + 6⋅y₃ + y₄ + y₅ + y₆ + y₇ + y₈)                                 2⋅k_{0_{12}}⋅
# ──────────────────────────────────────── + ───────────────────────────────────
#                                        2   k_{0_{12}}⋅(2.5⋅y₁ + y₂ + 6⋅y₃ + y₄
# ₂ + 6⋅y₃ + y₄ + y₅ + y₆ + y₇ + y₈)    ⎞    ───────────────────────────────────
# ────────────────────────────────── + 1⎟                        k_{\infty_{12}}
# {\infty_{12}}                         ⎠
#
#                       2
#                k_{0_4} ⋅y₂⋅y₄
# ─────────────────────────────────────────────────────────── + ────────────────
#                                                           2   k_{0_4}⋅(2.5⋅y₁
# _{0_4}⋅(2.5⋅y₁ + y₂ + 16⋅y₃ + y₄ + y₅ + y₆ + y₇ + y₈)    ⎞    ────────────────
# ───────────────────────────────────────────────────── + 1⎟
#                     k_{\infty_4}                         ⎠
#
#                                                                 0
#
# + k_{r_3}⋅y₃
#
#
#        k_{0_4}⋅y₂
# ───────────────────────────────────────── - k_{f_1}⋅y₂ + k_{f_6}⋅y₇
#  y₂ + 16⋅y₃ + y₄ + y₅ + y₆ + y₇ + y₈)
# ───────────────────────────────────── + 1
#     k_{\infty_4}
#
#
#
#
#
#
# ───────────────────── - k_{f_1}⋅y₂ - k_{f_5}⋅y₇ - k_{f_6}⋅y₇ - k_{r_2}⋅y₆ - k_
# ₅ + y₆ + y₇ + y₈)
# ───────────────── + 1
#
#
#
#
#
#
# y₈
# ───────────────────────── + k_{f_1}⋅y₂ + 2⋅k_{f_5}⋅y₇ - k_{f_8}⋅y₆ - k_{r_2}⋅y
#  + y₅ + y₆ + y₇ + y₈)
# ───────────────────── + 1
#
#
#
#
#         k_{0_4}⋅y₂
# ────────────────────────────────────────── - k_{f_5}⋅y₇ - k_{f_6}⋅y₇
# + y₂ + 16⋅y₃ + y₄ + y₅ + y₆ + y₇ + y₈)
# ────────────────────────────────────── + 1
#      k_{\infty_4}
#
#
#
#
#
#
#
#
#                                                          ─────────────────────
#
#                                                                       ⎛k_{0_4}
#                                                          k_{\infty_4}⋅⎜───────
#                                                                       ⎝
#
#
#
#
#
# {r_3}⋅y₃                                           ───────────────────────────
#
#                                                                 ⎛k_{0_4}⋅(2.5⋅
#                                                    k_{\infty_4}⋅⎜─────────────
#                                                                 ⎝
#
#
#
#                                        2
#                            2⋅k_{0_{12}} ⋅y₈⋅(2.5⋅y₁ + y₂ + 6⋅y₃ + y₄ + y₅ + y₆
# ₆ + k_{r_3}⋅y₃  - ────────────────────────────────────────────────────────────
#
#                                   ⎛k_{0_{12}}⋅(2.5⋅y₁ + y₂ + 6⋅y₃ + y₄ + y₅ +
#                   k_{\infty_{12}}⋅⎜───────────────────────────────────────────
#                                   ⎝                    k_{\infty_{12}}
#
#
#
#                                                                 ──────────────
#
#                                                                              ⎛
#                                                                 k_{\infty_4}⋅⎜
#                                                                              ⎝
#
#
#
#                  -k_{f_2}⋅y₁
#
#                 2
#          k_{0_4} ⋅y₂⋅y₄
# ───────────────────────────────────────────────────── + k_{r_1}⋅y₆
#                                                     2
# ⋅(2.5⋅y₁ + y₂ + 16⋅y₃ + y₄ + y₅ + y₆ + y₇ + y₈)    ⎞
# ─────────────────────────────────────────────── + 1⎟
#               k_{\infty_4}                         ⎠
#
#                       0
#
#           2
#    k_{0_4} ⋅y₂⋅y₄
# ─────────────────────────────────────────────── + k_{f_2}⋅y₁ + k_{r_1}⋅y₆
#                                               2
# y₁ + y₂ + 16⋅y₃ + y₄ + y₅ + y₆ + y₇ + y₈)    ⎞
# ───────────────────────────────────────── + 1⎟
#         k_{\infty_4}                         ⎠
#
#            -k_{f_2}⋅y₁ - k_{r_1}⋅y₆
#
#
#  + y₇ + y₈)                                 2⋅k_{0_{12}}⋅y₈
# ─────────────────── + ────────────────────────────────────────────────────────
#                   2   k_{0_{12}}⋅(2.5⋅y₁ + y₂ + 6⋅y₃ + y₄ + y₅ + y₆ + y₇ + y₈)
# y₆ + y₇ + y₈)    ⎞    ────────────────────────────────────────────────────────
# ───────────── + 1⎟                        k_{\infty_{12}}
#                  ⎠
#
#                        2
#                -k_{0_4} ⋅y₂⋅y₄
# ────────────────────────────────────────────────────────────
#                                                            2
# k_{0_4}⋅(2.5⋅y₁ + y₂ + 16⋅y₃ + y₄ + y₅ + y₆ + y₇ + y₈)    ⎞
# ────────────────────────────────────────────────────── + 1⎟
#                      k_{\infty_4}                         ⎠
#
#                       0
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                        2
#                                            2⋅k_{0_{12}} ⋅y₈⋅(2.5⋅y₁ + y₂ + 6⋅y
# ──── + k_{f_2}⋅y₁ - k_{r_1}⋅y₆  - ────────────────────────────────────────────
#
#  + 1                                              ⎛k_{0_{12}}⋅(2.5⋅y₁ + y₂ + 6
#                                   k_{\infty_{12}}⋅⎜───────────────────────────
#                                                   ⎝                    k_{\inf
#
#
#
#
#
#
#
#
#
#
#
#                                               -k_{f_3}⋅y₁ + k_{r_2}⋅y₄
#
#                                              2
#                                       k_{0_4} ⋅y₂⋅y₄
#         ──────────────────────────────────────────────────────────────────────
#
#                      ⎛k_{0_4}⋅(2.5⋅y₁ + y₂ + 16⋅y₃ + y₄ + y₅ + y₆ + y₇ + y₈)
#         k_{\infty_4}⋅⎜────────────────────────────────────────────────────── +
#                      ⎝                     k_{\infty_4}
#
#                                         k_{f_3}⋅y₁ + k_{f_7}⋅y₇ + k_{f_8}⋅y₄
#
#                                        2
#                                 k_{0_4} ⋅y₂⋅y₄
#   ────────────────────────────────────────────────────────────────────────── +
#                                                                            2
#                ⎛k_{0_4}⋅(2.5⋅y₁ + y₂ + 16⋅y₃ + y₄ + y₅ + y₆ + y₇ + y₈)    ⎞
#   k_{\infty_4}⋅⎜────────────────────────────────────────────────────── + 1⎟
#                ⎝                     k_{\infty_4}                         ⎠
#
#                                               -k_{r_1}⋅y₅ + k_{r_2}⋅y₄
#
#
# ₃ + y₄ + y₅ + y₆ + y₇ + y₈)                                 2⋅k_{0_{12}}⋅y₈
# ─────────────────────────────────── + ────────────────────────────────────────
#                                   2   k_{0_{12}}⋅(2.5⋅y₁ + y₂ + 6⋅y₃ + y₄ + y₅
# ⋅y₃ + y₄ + y₅ + y₆ + y₇ + y₈)    ⎞    ────────────────────────────────────────
# ───────────────────────────── + 1⎟                        k_{\infty_{12}}
# ty_{12}}                         ⎠
#
#                                                      2
#                                               k_{0_4} ⋅y₂⋅y₄
#               - ──────────────────────────────────────────────────────────────
#
#                              ⎛k_{0_4}⋅(2.5⋅y₁ + y₂ + 16⋅y₃ + y₄ + y₅ + y₆ + y₇
#                 k_{\infty_4}⋅⎜────────────────────────────────────────────────
#                              ⎝                     k_{\infty_4}
#
#                                                           0
#
#
#
#
#
# ──── + k_{f_7}⋅y₇ + k_{r_1}⋅y₅
#    2
#   ⎞
#  1⎟
#   ⎠
#
#
#
#
#
#  k_{f_3}⋅y₁ + k_{r_1}⋅y₅ - k_{r_2}⋅y₄
#
#
#
#
#
#
#
#
#
# ──────────────────── - k_{f_3}⋅y₁ - k_{f_7}⋅y₇ - k_{f_8}⋅y₄ - k_{r_1}⋅y₅ - k_{
#  + y₆ + y₇ + y₈)
# ──────────────── + 1
#
#
#
#
#
# ──────────── - k_{f_7}⋅y₇
#            2
#  + y₈)    ⎞
# ────── + 1⎟
#           ⎠
#
#
#
#
#
#                                                                          2
#                                                                   k_{0_4} ⋅y₂⋅
#                                     ──────────────────────────────────────────
#
#                                                  ⎛k_{0_4}⋅(2.5⋅y₁ + y₂ + 16⋅y₃
#                                     k_{\infty_4}⋅⎜────────────────────────────
#                                                  ⎝                     k_{\inf
#
#
#
#                                                                           2
#                                                                    k_{0_4} ⋅y₂
#                                      ─────────────────────────────────────────
#
#                                                   ⎛k_{0_4}⋅(2.5⋅y₁ + y₂ + 16⋅y
#                                      k_{\infty_4}⋅⎜───────────────────────────
#                                                   ⎝                     k_{\in
#
#
#
#                                 2
#                     2⋅k_{0_{12}} ⋅y₈⋅(2.5⋅y₁ + y₂ + 6⋅y₃ + y₄ + y₅ + y₆ + y₇ +
# r_2}⋅y₄  - ───────────────────────────────────────────────────────────────────
#
#                            ⎛k_{0_{12}}⋅(2.5⋅y₁ + y₂ + 6⋅y₃ + y₄ + y₅ + y₆ + y₇
#            k_{\infty_{12}}⋅⎜──────────────────────────────────────────────────
#                            ⎝                    k_{\infty_{12}}
#
#                                                            2
#                                                     k_{0_4} ⋅y₂⋅y₄
#                     - ────────────────────────────────────────────────────────
#
#                                    ⎛k_{0_4}⋅(2.5⋅y₁ + y₂ + 16⋅y₃ + y₄ + y₅ + y
#                       k_{\infty_4}⋅⎜──────────────────────────────────────────
#                                    ⎝                     k_{\infty_4}
#
#
#
#     k_{f_6}⋅y₄ - k_{f_{11}}⋅y₁
#
#
# y₄
# ──────────────────────────────── + k_{f_6}⋅y₄ + k_{f_7}⋅y₆ + 2⋅k_{f_{10}}⋅y₇
#                                2
#  + y₄ + y₅ + y₆ + y₇ + y₈)    ⎞
# ────────────────────────── + 1⎟
# ty_4}                         ⎠
#
#             k_{f_7}⋅y₆
#
#
# ⋅y₄
# ───────────────────────────────── - k_{f_5}⋅y₄ - k_{f_6}⋅y₄ + k_{f_{11}}⋅y₁
#                                 2
# ₃ + y₄ + y₅ + y₆ + y₇ + y₈)    ⎞
# ─────────────────────────── + 1⎟
# fty_4}                         ⎠
#
#                 0
#
#
#  y₈)                                 2⋅k_{0_{12}}⋅y₈
# ──────────── + ──────────────────────────────────────────────────────────── +
#            2   k_{0_{12}}⋅(2.5⋅y₁ + y₂ + 6⋅y₃ + y₄ + y₅ + y₆ + y₇ + y₈)
#  + y₈)    ⎞    ──────────────────────────────────────────────────────── + 1
# ────── + 1⎟                        k_{\infty_{12}}
#           ⎠
#
#
#
# ────────────────── - k_{f_5}⋅y₄ - k_{f_6}⋅y₄ - k_{f_7}⋅y₆ - 4⋅k_{f_{10}}⋅y₇ -
#                  2
# ₆ + y₇ + y₈)    ⎞
# ──────────── + 1⎟
#                 ⎠
#
#  2⋅k_{f_{10}}⋅y₇ + k_{f_{11}}⋅y₁
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                   2
#                                       2⋅k_{0_{12}} ⋅y₈⋅(2.5⋅y₁ + y₂ + 6⋅y₃ + y
# 2⋅k_{f_5}⋅y₄ - k_{f_7}⋅y₆  - ─────────────────────────────────────────────────
#
#                                              ⎛k_{0_{12}}⋅(2.5⋅y₁ + y₂ + 6⋅y₃ +
#                              k_{\infty_{12}}⋅⎜────────────────────────────────
#                                              ⎝                    k_{\infty_{1
#
#
#
# k_{f_{11}}⋅y₁
#
#
#
#
#
#
#
#                                                     0
#
#                                                     2
#                                              k_{0_4} ⋅y₂⋅y₄
#                ───────────────────────────────────────────────────────────────
#
#                             ⎛k_{0_4}⋅(2.5⋅y₁ + y₂ + 16⋅y₃ + y₄ + y₅ + y₆ + y₇
#                k_{\infty_4}⋅⎜─────────────────────────────────────────────────
#                             ⎝                     k_{\infty_4}
#
#                                                     0
#
#                                                     2
#                                              k_{0_4} ⋅y₂⋅y₄
#                ───────────────────────────────────────────────────────────────
#
#                             ⎛k_{0_4}⋅(2.5⋅y₁ + y₂ + 16⋅y₃ + y₄ + y₅ + y₆ + y₇
#                k_{\infty_4}⋅⎜─────────────────────────────────────────────────
#                             ⎝                     k_{\infty_4}
#
#                                                     0
#
#
# ₄ + y₅ + y₆ + y₇ + y₈)                                 2⋅k_{0_{12}}⋅y₈
# ────────────────────────────── + ─────────────────────────────────────────────
#                              2   k_{0_{12}}⋅(2.5⋅y₁ + y₂ + 6⋅y₃ + y₄ + y₅ + y₆
#  y₄ + y₅ + y₆ + y₇ + y₈)    ⎞    ─────────────────────────────────────────────
# ──────────────────────── + 1⎟                        k_{\infty_{12}}
# 2}}                         ⎠
#
#                                                     2
#                                             -k_{0_4} ⋅y₂⋅y₄
#                ───────────────────────────────────────────────────────────────
#
#                             ⎛k_{0_4}⋅(2.5⋅y₁ + y₂ + 16⋅y₃ + y₄ + y₅ + y₆ + y₇
#                k_{\infty_4}⋅⎜─────────────────────────────────────────────────
#                             ⎝                     k_{\infty_4}
#
#                                                     0
#
#
#
#
#
# ───────────
#           2
# + y₈)    ⎞
# ───── + 1⎟
#          ⎠
#
#
#
#
#
# ───────────
#           2
# + y₈)    ⎞
# ───── + 1⎟
#          ⎠
#
#
#
#
#                    2⋅k_{0_{12}}⋅(2.5⋅y₁ + y₂ + 6⋅y₃ + y₄ + y₅ + y₆ + y₇ + y₈)
# ─────────────── + ────────────────────────────────────────────────────────────
#  + y₇ + y₈)       k_{0_{12}}⋅(2.5⋅y₁ + y₂ + 6⋅y₃ + y₄ + y₅ + y₆ + y₇ + y₈)
# ─────────── + 1   ──────────────────────────────────────────────────────── + 1
#                                       k_{\infty_{12}}
#
#
#
#
# ───────────
#           2
# + y₈)    ⎞
# ───── + 1⎟
#          ⎠
#
#
#
# ⎤
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎥
# ⎦
